# %% [markdown]
# # Instruction
# - Exam time from 0900 to 1200
# - Submit your notebook in AIT TEAL in `Midterm Submission`
# - The exam is openbook/open web.
# - You are not allowed to use any GenAI tools.

# %% [markdown]
# ---

# %% [markdown]
# # Question 1 : Linear Shift Invariance System `(10 points)`
# Please explain properties of LSIS
#
# ![Screenshot 2567-10-04 at 23.40.26.png](data:image/png;base64,...)

# %% [markdown]
# `Your answer here`
#
# LSIS is a system that has both linearity and shift variance and its used to process signals

# %% [markdown]
# # 📘 Question 1: Linear Shift Invariant System (LSIS)
#
# LSIS is a system that obeys **linearity** (superposition) and **shift invariance** (shift in input → same shift in output), fully described by **convolution with an impulse response**.
#
# ---
#
# ## 🔹 Properties of LSIS
#
# 1. **Linearity (Superposition Property):**
#    - If the system receives a linear combination of inputs, the output is the same combination of individual outputs.
#    - Mathematically:
#      $$
#      S\big[a f_1(x) + b f_2(x)\big] = a S[f_1(x)] + b S[f_2(x)]
#      $$
#
# 2. **Shift Invariance (Time/Space Invariance):**
#    - If the input is shifted, the output shifts in the same way.
#    - Mathematically:
#      $$
#      f(x - x_0) \;\;\longrightarrow\;\; g(x - x_0)
#      $$
#
# 3. **Convolution Property:**
#    - An LSIS is fully characterized by its **impulse response** $h(x)$.
#    - The output is the **convolution** of the input with $h(x)$:
#      $$
#      g(x) = f(x) * h(x) = \int_{-\infty}^{\infty} f(\tau)\, h(x - \tau)\, d\tau
#      $$
#
# ---
#
# ## 🔹 Why LSIS is Important
# - Used in **signal processing** (audio, radar, communications).
# - Used in **image processing** (blurring, sharpening, edge detection).
# - Provides a **mathematical framework** for describing filters and transformations.
#
# ---
#
# # ✅ Short Answer (for quick use in slides)
#
# LSIS has two key properties: **linearity** (obeys superposition) and **shift invariance** (shift in input → same shift in output).
# Such systems are described using **convolution with an impulse response**, making them fundamental in signal and image processing.
#
# ---
#
# ## LSIS Properties (Summary)
#
# 1. **Linearity → Superposition**
#    S[a·f1(x) + b·f2(x)] = a·S[f1(x)] + b·S[f2(x)]
#
# 2. **Shift Invariance**
#    f(x − x0) → g(x − x0)
#
# 3. **Convolution Representation**
#    g(x) = f(x) * h(x)
#
#
# ## 🔹 Real-World Example: Image Blurring
# Suppose we apply a **Gaussian blur** filter to an image.
#
# - **Linearity:** If we blur two images separately and then add them, the result is the same as adding the images first and then blurring once.
# - **Shift Invariance:** If we shift the image (move it right by 10 pixels), the blurred result will also shift by 10 pixels.
# - **Convolution:** The blurring process can be expressed as convolution of the image with a Gaussian kernel.
#
# 👉 This shows how LSIS explains everyday image processing tasks like smoothing, sharpening, and edge detection.

# %% [markdown]
# # Question 2 : Bilateral Filter

# %% [markdown]
# ## Q 2.1 : Write a python code to apply the following filters to a given image, `(5 points)`
# - Gaussian filter with `kernel size = 9` and `sigmaX = sigmaY = 50`
# - Bilateral filter with `kernel size = 9` and  `spatial and color sigma = 90`
# - Show the result images side-by-side
#
# Input image is in `assets/q2`.
#
# Analyze the differences in the results. Explain why the bilateral filter is better at preserving edges.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img =cv2.imread('assets/q2/face-image.jpg')

gaussian_img= cv2.GaussianBlur(img,(9, 9),sigmaX=50, sigmaY=50)

bilateral_img= cv2.bilateralFilter(img, 9,90, 90)

fig, axes =plt.subplots(1, 3,figsize=(15,5))
axes[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
axes[0].set_title('Original Image')
axes[1].imshow(cv2.cvtColor(gaussian_img, cv2.COLOR_BGR2RGB))
axes[1].set_title('Gaussian Filter')
axes[2].imshow(cv2.cvtColor(bilateral_img, cv2.COLOR_BGR2RGB))
axes[2].set_title('Bilateral Filter')
plt.show()

# %% [markdown]
# #### gausian filter is linear and bilateral is non linear filter
# #####  both reduces noise but gausian filter  also blurs the edges and bilateral filter preserves the edges
# #####  bilateral filter is better at preserving edges beacuse it uses a neighbour pixels weighted averages based in intensity difference
#
#
# ## Result/Analysis:
#
# #####  Gaussian blur smooths the entire image, including edges → edges appear blurred.
#
# #####  Bilateral filter smooths flat regions but preserves edges by considering both spatial distance and color similarity.
#
# #####  This makes the bilateral filter better for denoising natural images where edges should remain sharp.
#
# 🔹 Short Explanation (Q2.1)
#
# Gaussian filter smooths the whole image, but it also blurs edges.
#
# Bilateral filter smooths flat regions while preserving edges, because it considers both spatial closeness and color similarity.
#
# This makes it better for tasks where sharp boundaries are important.

# %% [markdown]
# ## Q 2.2 : Write a python code to apply a bilateral filter with the following spatial and color (Brightness) sigma values and show the results `(15 points)`
#
# Spatial Sigma | Color Sigma
#
# <table>
# <tr>
#     <th>Spatial Sigma</th>
#     <th>Color Sigma</th>
# </tr>
#
# <tr>
#     <td>9</td>
#     <td>9</td>
# </tr>
#
# <tr>
#     <td>9</td>
#     <td>75</td>
# </tr>
#
# <tr>
#     <td>9</td>
#     <td>500</td>
# </tr>
#
# <tr>
#     <td>75</td>
#     <td>9</td>
# </tr>
#
# <tr>
#     <td>500</td>
#     <td>9</td>
# </tr>
# </table>
#
# Note that `d=9` for all sigma.
#
# Explain how the choice of sigma values affects the filtering results

# %%
# Your code here
img =cv2.imread('assets/q2/face-image.jpg')

# sigma_values = [
#     (9, 9),
#     (9, 75),
#     (9, 500),
#     (75, 9),
#     (500, 9)
# ]

# fig, axes = plt.subplots(1, len(sigma_values) + 1, figsize=(20, 5))

# # orignal image
# axes[0].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# axes[0].set_title('Original Image')

# # applying sigma values
# for i, (spatial_sigma, color_sigma) in enumerate(sigma_values):
#     bilateral_img = cv2.bilateralFilter(img, 9, color_sigma, spatial_sigma)
#     axes[i + 1].imshow(cv2.cvtColor(bilateral_img, cv2.COLOR_BGR2RGB))
#     axes[i + 1].set_title(f'Spatial Sigma: {spatial_sigma}, Color Sigma: {color_sigma}')

# plt.tight_layout()
# plt.show()

# Different sigma combinations
sigma_pairs = [
    (9, 9),
    (9, 75),
    (9, 500),
    (75, 9),
    (500, 9)
]

plt.figure(figsize=(15,10))

for i, (sigma_space, sigma_color) in enumerate(sigma_pairs, 1):
    filtered = cv.bilateralFilter(img, d=9,
                                  sigmaColor=sigma_color,
                                  sigmaSpace=sigma_space)
    plt.subplot(2,3,i)
    plt.imshow(cv.cvtColor(filtered, cv.COLOR_BGR2RGB))
    plt.title(f"σSpace={sigma_space}, σColor={sigma_color}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# smaller spatial sigma values preserves more details and keep its quality good,  while the larger sigma values blures the images more
# smaller color sigma value preserves more color details,  while the larger sigma doesnot keep much details of orignal colours

# %% [markdown]
# ### Result/Analysis:
#
# (σSpace=9, σColor=9): Mild smoothing, edges mostly preserved.
#
# (σSpace=9, σColor=75): Stronger smoothing inside similar-colored regions, edges still preserved.
#
# (σSpace=9, σColor=500): Heavy smoothing everywhere (similar to Gaussian), edges begin to blur.
#
# (σSpace=75, σColor=9): Smoothing spreads far spatially, but low color sigma → weak effect.
#
# (σSpace=500, σColor=9): Very wide neighborhood but still only small effect due to strict color similarity.
#
# ✅ Key takeaway:
#
# High σColor → ignores color differences → strong blur.
#
# High σSpace → larger spatial averaging → smoother image.
#
# Bilateral filter effectiveness depends on balancing both parameters: too high → Gaussian-like blur, too low → little effect.
#
# 🔹 Short Explanation (Q2.2)
#
# Low spatial sigma (σSpace small): filtering is very local, edges stay sharp but noise may remain.
#
# High spatial sigma (σSpace large): filtering considers far-away pixels, stronger smoothing but edges risk getting blurred.
#
# Low color sigma (σColor small): only very similar colors are averaged, edges well-preserved but less denoising.
#
# High color sigma (σColor large): more aggressive smoothing across different colors, risk of edge blurring.
#
# 👉 The balance of σSpace and σColor controls the trade-off between denoising and edge preservation.

# %% [markdown]
# # Question 3 : SIFT and Image Alignment
#
#
# Using `SIFT`detector, detect `feature points` and calculate `descriptors`. Then `match` correnspondences between two given images in `assets/q3`.

# %% [markdown]
# ## Q 3.1 : Draw keypoints for each image. `(5 points)`

# %%
# # Your code here
# import cv2 as cv
# import numpy as np
# import matplotlib.pyplot as plt

# img1=cv2.imread('assets/q3/book_scene.jpeg')
# img2=cv2.imread('assets/q3/book.jpeg')

# gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
# gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
# sift = cv2.SIFT_create()

# keypoints1, descriptors1 = sift.detectAndCompute(gray1, None)
# keypoints2, descriptors2 = sift.detectAndCompute(gray2, None)
# img1_kp = cv2.drawKeypoints(img1, keypoints1, None, flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
# img2_kp = cv2.drawKeypoints(img2, keypoints2, None, flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# fig, axes = plt.subplots(1, 2, figsize=(12, 6))
# axes[0].imshow(cv2.cvtColor(img1_kp, cv2.COLOR_BGR2RGB))
# axes[0].set_title('Image 1 Keypoints')
# axes[1].imshow(cv2.cvtColor(img2_kp, cv2.COLOR_BGR2RGB))
# axes[1].set_title('Image 2 Keypoints')
# plt.show()

import cv2 as cv
import matplotlib.pyplot as plt

# Load images
img1 = cv.imread("assets/q3/book_scene.jpeg")
img2 = cv.imread("assets/q3/book.jpeg")

gray1 = cv.cvtColor(img1, cv.COLOR_BGR2GRAY)
gray2 = cv.cvtColor(img2, cv.COLOR_BGR2GRAY)

# Initialize SIFT
sift = cv.SIFT_create()

# Detect keypoints
kp1, des1 = sift.detectAndCompute(gray1, None)
kp2, des2 = sift.detectAndCompute(gray2, None)

# Draw keypoints
img1_kp = cv.drawKeypoints(img1, kp1, None, flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
img2_kp = cv.drawKeypoints(img2, kp2, None, flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.imshow(cv.cvtColor(img1_kp, cv.COLOR_BGR2RGB))
plt.title("Book Scene Keypoints")
plt.axis("off")
plt.subplot(1,2,2)
plt.imshow(cv.cvtColor(img2_kp, cv.COLOR_BGR2RGB))
plt.title("Book Cover Keypoints")
plt.axis("off")
plt.show()

print("Number of keypoints in scene:", len(kp1))
print("Number of keypoints in book:", len(kp2))
# Out:
# Number of keypoints in scene: 4086
# Number of keypoints in book: 1248

# %% [markdown]
# ## Q 3.2 : Draw the matched keypoints `(5 points)`

# %%
# Your code here
# I copied this code from lab work
# def match_features(descriptors1, descriptors2):
#     # Initialize BFMatcher with default parameters
#     bf = cv.BFMatcher(cv.NORM_L2, crossCheck=True)

#     # Match descriptors
#     matches = bf.match(descriptors1, descriptors2)

#     # Sort them in the order of their distance (best matches first)
#     matches = sorted(matches, key=lambda x: x.distance)

#     return matches

# matches = match_features(descriptors1, descriptors2)
# match_img = cv2.drawMatches(img1, keypoints1, img2, keypoints2, matches, None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# # Display the matched keypoints
# plt.imshow(cv2.cvtColor(match_img, cv2.COLOR_BGR2RGB))


# Match descriptors using BFMatcher
bf = cv.BFMatcher(cv.NORM_L2, crossCheck=True)
matches = bf.match(des1, des2)
matches = sorted(matches, key=lambda x: x.distance)

# Draw top 50 matches
img_matches = cv.drawMatches(img1, kp1, img2, kp2, matches[:50], None,
                             flags=cv.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

plt.figure(figsize=(15,6))
plt.imshow(cv.cvtColor(img_matches, cv.COLOR_BGR2RGB))
plt.title("Matched Keypoints (Top 50)")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Q 3.3 : Plot the `most` similar keypoint pair using their `descriptors` `(5 points)`

# %%
# # Your code here
# # I copied this code from lab work

# points1 = np.zeros((len(matches), 2), dtype=np.float32)
# points2 = np.zeros((len(matches), 2), dtype=np.float32)

# for i, match in enumerate(matches):
#     points1[i, :] = keypoints1[match.queryIdx].pt
#     points2[i, :] = keypoints2[match.trainIdx].pt

# fig, axes = plt.subplots(1, 2, figsize=(12, 6))
# axes[0].imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))
# axes[0].scatter(points1[0, 0], points1[0, 1], c='r', s=100)
# axes[0].set_title('Image 1')
# axes[1].imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
# axes[1].scatter(points2[0, 0], points2[0, 1], c='r', s=100)
# axes[1].set_title('Image 2')
# # plt.show()

# Find best match
best_match = min(matches, key=lambda x: x.distance)

pt1 = kp1[best_match.queryIdx].pt
pt2 = kp2[best_match.trainIdx].pt

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].imshow(cv.cvtColor(img1, cv.COLOR_BGR2RGB))
axes[0].scatter(pt1[0], pt1[1], c='r', s=80, marker='o')
axes[0].set_title("book_scene")
axes[0].axis("off")

axes[1].imshow(cv.cvtColor(img2, cv.COLOR_BGR2RGB))
axes[1].scatter(pt2[0], pt2[1], c='r', s=80, marker='o')
axes[1].set_title("book")
axes[1].axis("off")

plt.show()

print("Best match distance:", best_match.distance)
print("Book Scene point:", pt1)
print("Book Cover point:", pt2)
# Out:
# Best match distance: 23.237899780273438
# Book Scene point: (816.268310546875, 896.0638427734375)
# Book Cover point: (261.91748046875, 339.22186279296875)

# %% [markdown]
# ## Q 3.4 : Change a parameter of SIFT_create() function to increase the number of images in a scale-space to =`5`, and find `keypoints` and `descriptors` in `book_scene.jpeg` only. Analyze how the result (keypoints) changes in response to this parameter change. `(5 points)`

# %%
#### By default (nOctaveLayers=3), SIFT detected 4086 keypoints in the image. When increasing the parameter to nOctaveLayers=5, the number of detected keypoints increased significantly. This happens because a denser scale-space representation allows SIFT to capture more fine-grained details and multi-scale features, especially from textured regions of the image.

### The benefit is that feature matching becomes more robust since more distinctive points are available. However, this also increases computational cost, as the algorithm needs to process more layers per octave, making it slower and more resource-intensive.

### ✅ In conclusion, increasing nOctaveLayers improves the richness of detected features at the expense of extra computation time.

# %%
# Q3.4: SIFT Keypoint Detection with different scale-space parameters

import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# Load image
img = cv.imread('assets/q3/book_scene.jpeg')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# --- Default SIFT (nOctaveLayers=3) ---
sift = cv.SIFT_create()
kp, des = sift.detectAndCompute(gray, None)
img_kp = cv.drawKeypoints(img, kp, None, flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.imshow(cv.cvtColor(img_kp, cv.COLOR_BGR2RGB))
plt.title('Default Keypoints')
plt.axis("off")
plt.show()
print("Number of keypoints (default):", len(kp))

# --- Modified SIFT (nOctaveLayers=5) ---
sift5 = cv.SIFT_create(nOctaveLayers=5)
kp5, des5 = sift5.detectAndCompute(gray, None)
img_kp5 = cv.drawKeypoints(img, kp5, None, flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

plt.imshow(cv.cvtColor(img_kp5, cv.COLOR_BGR2RGB))
plt.title('Keypoints with nOctaveLayers=5')
plt.axis("off")
plt.show()
print("Number of keypoints (nOctaveLayers=5):", len(kp5))

# --- Analysis (for report) ---
print("\nAnalysis:")
print(f"Default (nOctaveLayers=3): {len(kp)} keypoints")
print(f"Modified (nOctaveLayers=5): {len(kp5)} keypoints")
print("Increasing the number of octave layers increases the number of detected keypoints, "
      "making SIFT more sensitive to fine details at different scales. "
      "However, it also increases computation time and cost.")
# Out:
# Number of keypoints (default): 4086
# Number of keypoints (nOctaveLayers=5): 4866
#
# Analysis:
# Default (nOctaveLayers=3): 4086 keypoints
# Modified (nOctaveLayers=5): 4866 keypoints
# Increasing the number of octave layers increases the number of detected keypoints, making SIFT more sensitive to fine details at different scales. However, it also increases computation time and cost.

# %% [markdown]
# # Question 4 : Canny Edge Detection `(25 points)`
#
# Complete a self defined Class for Canny Edge Detection by implementing
# - Non-maximum suppression
# - Double Thresholding
# - Use an image in `assets/q4` as an input

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

class CannyEdgeDetector:
    def __init__(self, img):
        self.img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
        self.gaussian_blur = None
        self.gradient_magnitude = None
        self.suppressed = None
        self.thresholded = None

    def apply_gaussian_blur(self, kernel_size=5):
        self.gaussian_blur = cv.GaussianBlur(self.img, (kernel_size, kernel_size), 1.4)
        return self.gaussian_blur

    def compute_gradient(self):
        gx = cv.Sobel(self.gaussian_blur, cv.CV_64F, 1, 0, ksize=3)
        gy = cv.Sobel(self.gaussian_blur, cv.CV_64F, 0, 1, ksize=3)
        self.magnitude = np.sqrt(gx**2 + gy**2)
        self.direction = np.arctan2(gy, gx)
        return self.magnitude, self.direction

    def non_maximum_suppression(self):
        rows, cols = self.magnitude.shape
        self.suppressed = np.zeros((rows, cols), dtype=np.int32)
        angle = self.direction * 180 / np.pi # Convert angle to radian
        angle[angle < 0] += 180
        for i in range(1, rows-1):
            for j in range(1, cols-1):
              q = 255
              r = 255

              # angle 0
              if (0 <= angle[i,j] < 22.5) or (157.5 <= angle[i,j] <= 180):
                    q = self.magnitude[i, j+1]
                    r = self.magnitude[i, j-1]
                # angle 45
              elif (22.5 <= angle[i,j] < 67.5):
                    q = self.magnitude[i+1, j-1]
                    r = self.magnitude[i-1, j+1]
                # angle 90
              elif (67.5 <= angle[i,j] < 112.5):
                    q = self.magnitude[i+1, j]
                    r = self.magnitude[i-1, j]
                # angle 135
              elif (112.5 <= angle[i,j] < 157.5):
                    q = self.magnitude[i-1, j-1]
                    r = self.magnitude[i+1, j+1]

              if (self.magnitude[i,j] >= q) and (self.magnitude[i,j] >= r):
                    self.suppressed[i,j] = self.magnitude[i,j]
              else:
                    self.suppressed[i,j] = 0

             #----------------
             # Your code here
             #----------------
             

        return self.suppressed


    def threshold(self, lowThresholdRatio=0.05, highThresholdRatio=0.09):
        rows, cols = self.suppressed.shape
        self.thresholded = np.zeros((rows,cols), dtype=np.int32)

        highThreshold = self.suppressed.max() * highThresholdRatio;
        lowThreshold = highThreshold * lowThresholdRatio;

        weak = np.int32(25)
        strong = np.int32(255)

        strong_i, strong_j = np.where(self.suppressed >= highThreshold)
        weak_i, weak_j = np.where((self.suppressed <= highThreshold) & (self.suppressed >= lowThreshold))

        #----------------
        # Your code here
        #----------------

        self.thresholded[strong_i, strong_j] = strong
        self.thresholded[weak_i, weak_j] = weak

        return self.thresholded


    def hysteresis(self, weak=25, strong=255):
        rows, cols = self.thresholded.shape
        for i in range(1, rows-1):
            for j in range(1, cols-1):
                if (self.thresholded[i, j] == weak):
                    if (
                        (self.thresholded[i+1, j-1] == strong) or (self.thresholded[i+1, j] == strong) or
                        (self.thresholded[i+1, j+1] == strong) or (self.thresholded[i, j-1] == strong) or
                        (self.thresholded[i, j+1] == strong) or (self.thresholded[i-1, j-1] == strong) or
                        (self.thresholded[i-1, j] == strong) or (self.thresholded[i-1, j+1] == strong)
                    ):
                        self.thresholded[i, j] = strong
                    else:
                        self.thresholded[i, j] = 0
        return self.thresholded


# Example usage with intermediate steps plotted
# Load image
img = cv.imread("assets/q4/brain_mri.png")

# Run pipeline
canny = CannyEdgeDetector(img)
gs = canny.apply_gaussian_blur()
gm, gd = canny.compute_gradient()
nms = canny.non_maximum_suppression()
th = canny.threshold()
hy = canny.hysteresis()

# Plot results
fig, ax = plt.subplots(2, 3, figsize=(15, 5))
ax[0,0].imshow(img, cmap='gray'); ax[0,0].set_title("Original Image"); ax[0,0].axis("off")
ax[0,1].imshow(gs, cmap='gray'); ax[0,1].set_title("Gaussian Blur"); ax[0,1].axis("off")
ax[0,2].imshow(gm, cmap='gray'); ax[0,2].set_title("Gradient Magnitude"); ax[0,2].axis("off")
ax[1,0].imshow(nms, cmap='gray'); ax[1,0].set_title("NMS"); ax[1,0].axis("off")
ax[1,1].imshow(th, cmap='gray'); ax[1,1].set_title("Threshold"); ax[1,1].axis("off")
ax[1,2].imshow(hy, cmap='gray'); ax[1,2].set_title("Hysteresis"); ax[1,2].axis("off")
plt.show()

#https://chatgpt.com/share/68d9dfed-2438-8008-9dd9-83dc754577f3

# %%
fig, ax = plt.subplots(2, 3, figsize=(15, 5))
ax[0,0].imshow(img, cmap='gray')
ax[0,0].set_title('Original Image')
ax[0,0].axis("off")
ax[0,1].imshow(gs, cmap='gray')
ax[0,1].set_title('Gaussian Blur')
ax[0,1].axis("off")
ax[0,2].imshow(gm, cmap='gray')
ax[0,2].set_title('Gradient Magnitude')
ax[0,2].axis("off")
ax[1,0].imshow(nms, cmap='gray')
ax[1,0].set_title('NMS')
ax[1,0].axis("off")
ax[1,1].imshow(th, cmap='gray')
ax[1,1].set_title('Threshold')
ax[1,1].axis("off")
ax[1,2].imshow(hy, cmap='gray')
ax[1,2].set_title('Hysteresis')
ax[1,2].axis("off")
plt.show()

# %% [markdown]
# # Question 5 :

# %% [markdown]
# ## Q 5.1 : Implement a basic CNN in PyTorch for classifying images in the `CIFAR10` dataset. Your CNN should have `(20 points)`
# - `2` convolutional layers with `11x11`, and `5x5` kernel sizes respectively
# - `2` max-pooling layers with size of `3x3`
# - `2` fully connected layers with size of `1024` and `10`
# - Model architecture: `Input -> Conv -> Pool -> Conv -> Pool -> FC -> FC`
#
# Train your model with the following hyperparameters
# - Subsample dataset: `1,000` samples
# - resize images to the size of : `224x224`
# - Split data into `3 datasets`: Train, Val, and Test (you can choose yourself a number of samples in each set)
# - Batch_size: `64`
# - Epoch: `15`
# - learning_rate: `0.001`
# - Optimizer: your choice
#
#
# Report the following
# - accuracy and loss on Training and Validation dataset
# - accuracy on the test set.
# - number of learnable parameters

# %%
# For our puffer surver we need to browse via a proxy!!
import os
# Set HTTP and HTTPS proxy
os.environ['http_proxy'] = 'http://192.41.170.23:3128'
os.environ['https_proxy'] = 'http://192.41.170.23:3128'

# %%
# Your code here

# %%
transform = transforms.Compose([
    # Your code here
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 transform = transforms.Compose([
#       2     # Your code here
#       3     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       4 ])
#
# NameError: name 'transforms' is not defined

# %%
# Download CIFAR-10 dataset (or use your own dataset)
train_dataset = datasets.CIFAR10(root='./data', train=True, transform=transform, download=True)
test_dataset = datasets.CIFAR10(root='./data', train=False, transform=transform, download=True)

# %%
# Your code here

# %%
# Load the data
train_loader = torch.utils.data.DataLoader(Your code here)
# Your code here

# %%
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []

def train():
    cnn_model.train()
    train_corr, train_total, train_running_loss = 0, 0, 0  # counters for tracting trainning accuracy, total examples, running loss

    for step, (data, y) in enumerate(train_loader):        # loops over batch of data in train_loader
        data, y = data.to(device), y.to(device)

        # --------------------------
        # Your code here
        # --------------------------

        y_pred = torch.argmax(logits, 1)                     # selects the predicted class (the index with the highest value)
        train_corr += torch.sum(torch.eq(y_pred, y).float()).item()      # counts correct predictions
        train_total += len(data)                             # tracks total no. of samples
        train_running_loss += loss.item()                    # accumulates loss

    # Calculate average loss and accuracy for this epoch
    epoch_loss = train_running_loss / len(train_loader)
    epoch_accuracy = train_corr / train_total

    # Append to lists for plotting
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)

    print(f'Epoch [{epoch+1}] Train Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}')

# %%
def test():
    # Your code here !!! sets model to evalutaion mode
    test_corr, test_total, test_running_loss = 0, 0, 0
    with torch.no_grad():
        for step, (data, y) in enumerate(test_loader):
            data, y = data.to(device), y.to(device)
            _, logits = cnn_model(data)
            loss = loss_fn(logits, y)
            y_pred = torch.argmax(logits, 1)
            test_corr += torch.sum(torch.eq(y_pred, y).float()).item()
            test_total += len(data)
            test_running_loss += loss.item()
    # Calculate average loss and accuracy for this epoch
    epoch_loss = test_running_loss / len(test_loader)
    epoch_accuracy = test_corr / test_total

    # Append to lists for plotting
    test_losses.append(epoch_loss)
    test_accuracies.append(epoch_accuracy)

    print(f'Epoch [{epoch+1}] Test Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.4f}')

# %%
for epoch in range(num_epoch):
  # ----------
  # Your code here
  # ----------

# Test a model
test()

# %% [markdown]
# ## Q 5.2 : Define the new model architecture that have `(15 points)`
# - `3` convolutional layers with `3x3`kernel sizes
# - `2` max-pooling layers with size of `3x3`
# - `2` fully connected layers with size of `1024` and `10`
# - Model architecture: `Input -> Conv -> Conv -> Pool -> Conv -> Pool -> FC -> FC`
#
# Train the new model with the same hyperparameters as above
#
# Report the following
# - accuracy and loss on Training and Validation dataset
# - accuracy on the test set.
# - number of learnable parameters

# %% [markdown]
# ## Q 5.3 : Compare the performance of these models. Analyze the strengths and weaknesses of each model. `(10 points)`

# %% [markdown]
# `Your Answer here !!!`

# %%
import cv2
import matplotlib.pyplot as plt

# Read an image (replace 'image.jpg' with your file)
img = cv2.imread('assets/redball.jpg')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# 1. Gaussian filter
gaussian = cv2.GaussianBlur(img_rgb, (9, 9), sigmaX=50, sigmaY=50)

# 2. Bilateral filter
bilateral = cv2.bilateralFilter(img_rgb, d=9, sigmaColor=90, sigmaSpace=90)

# 3. Show results side-by-side
titles = ['Original Image', 'Gaussian Filter (k=9, σ=50)', 'Bilateral Filter (k=9, σ=90)']
images = [img_rgb, gaussian, bilateral]

plt.figure(figsize=(15, 8))
for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()
